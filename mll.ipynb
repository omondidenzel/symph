# %%
import sympy as smp
import numpy as np 
import scipy as sp 
import matplotlib.pyplot as plt 
from scipy.misc import derivative
import math
import pandas as pd

import warnings 
warnings.filterwarnings("ignore")

# %%
smp.init_session()
# Out:
# IPython console for SymPy 1.9 (Python 3.9.7-64-bit) (ground types: gmpy)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.9/

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
eqn = smp.Eq(x+9, 8)
eqn
# Out:
# x + 9 = 8

# %%
solve(eqn)
# Out:
# [-1]

# %%
solve(Eq(x+9, 8))
# Out:
# [-1]

# %%
eqn = Eq(8*x**2, 7*x+51)
eqn
# Out:
#    2
# 8⋅x  = 7⋅x + 51

# %%
solve(eqn)
# Out:
# [-17/8, 3]

# %%
x , a, b, c = smp.symbols('x a b c', real = True)

# %%
f = smp.exp(-a * smp.sin(pow(x, 2))) * smp.sin(pow(b, x)) * smp.log(c * smp.sin(x) **2 /x)
f
# Out:
#        ⎛ 2⎞    ⎛     2   ⎞
#  -a⋅sin⎝x ⎠    ⎜c⋅sin (x)⎟    ⎛ x⎞
# ℯ          ⋅log⎜─────────⎟⋅sin⎝b ⎠
#                ⎝    x    ⎠

# %%
dfdx = smp.diff(f, x)
dfdx
# Out:
#
#
#
#                ⎛ 2⎞    ⎛     2   ⎞                             ⎛ 2⎞
#          -a⋅sin⎝x ⎠    ⎜c⋅sin (x)⎟    ⎛ x⎞    ⎛ 2⎞    x  -a⋅sin⎝x ⎠
# - 2⋅a⋅x⋅ℯ          ⋅log⎜─────────⎟⋅sin⎝b ⎠⋅cos⎝x ⎠ + b ⋅ℯ          ⋅log(b)⋅log
#                        ⎝    x    ⎠
#
#
#                         ⎛                         2   ⎞        ⎛ 2⎞
#                         ⎜2⋅c⋅sin(x)⋅cos(x)   c⋅sin (x)⎟  -a⋅sin⎝x ⎠    ⎛ x⎞
#                       x⋅⎜───────────────── - ─────────⎟⋅ℯ          ⋅sin⎝b ⎠
# ⎛     2   ⎞             ⎜        x                2   ⎟
# ⎜c⋅sin (x)⎟    ⎛ x⎞     ⎝                        x    ⎠
# ⎜─────────⎟⋅cos⎝b ⎠ + ─────────────────────────────────────────────────────
# ⎝    x    ⎠                                      2
#                                             c⋅sin (x)

# %%
dfdx4 = smp.diff(f, x, 4)
dfdx4
# Out:
# ⎛
# ⎜
# ⎜
# ⎜
# ⎜
# ⎜      x   ⎛ x    ⎛ x⎞      ⎛ x⎞⎞ ⎛           sin(x)⎞    2       ⎛ 2⎞
# ⎜24⋅a⋅b ⋅x⋅⎝b ⋅sin⎝b ⎠ - cos⎝b ⎠⎠⋅⎜2⋅cos(x) - ──────⎟⋅log (b)⋅cos⎝x ⎠
# ⎜                                 ⎝             x   ⎠                        x
# ⎜──────────────────────────────────────────────────────────────────── + 8⋅a⋅b
# ⎝                               sin(x)
#
#
#
#
#
#
#
#                                                       ⎛     2   ⎞           24
#    ⎛ 2⋅x    ⎛ x⎞      x    ⎛ x⎞      ⎛ x⎞⎞    3       ⎜c⋅sin (x)⎟    ⎛ 2⎞
# ⋅x⋅⎝b   ⋅cos⎝b ⎠ + 3⋅b ⋅sin⎝b ⎠ - cos⎝b ⎠⎠⋅log (b)⋅log⎜─────────⎟⋅cos⎝x ⎠ + ──
#                                                       ⎝    x    ⎠
#
#
#         ⎛                                 ⎛
#         ⎜                                 ⎜   2         2      2⋅sin(x)⋅cos(x)
#         ⎜  ⎛           sin(x)⎞          2⋅⎜sin (x) - cos (x) + ───────────────
#         ⎜2⋅⎜2⋅cos(x) - ──────⎟⋅cos(x)     ⎜                           x
#     x   ⎜  ⎝             x   ⎠            ⎝
# ⋅a⋅b ⋅x⋅⎜──────────────────────────── + ──────────────────────────────────────
#         ⎝           sin(x)                                    sin(x)
# ──────────────────────────────────────────────────────────────────────────────
#                                                                sin(x)
#
#
#       2   ⎞                    ⎞
#    sin (x)⎟                    ⎟
#  - ───────⎟              sin(x)⎟
#        2  ⎟   2⋅cos(x) - ──────⎟
#       x   ⎠                x   ⎟           ⎛ x⎞    ⎛ 2⎞
# ─────────── - ─────────────────⎟⋅log(b)⋅cos⎝b ⎠⋅cos⎝x ⎠
#                       x        ⎠                                x   ⎛     2  2
# ─────────────────────────────────────────────────────── + 16⋅a⋅b ⋅x⋅⎝- 2⋅a ⋅x
#
#
#
#
#
#
#
#
#
#     3⎛ 2⎞        2    ⎛ 2⎞    ⎛ 2⎞          2⎛ 2⎞      2    ⎛ 2⎞        ⎛ 2⎞⎞
# ⋅cos ⎝x ⎠ - 6⋅a⋅x ⋅sin⎝x ⎠⋅cos⎝x ⎠ + 3⋅a⋅cos ⎝x ⎠ + 2⋅x ⋅cos⎝x ⎠ + 3⋅sin⎝x ⎠⎠⋅
#
#
#
#
#
#
#
#
#           ⎛     2   ⎞
#           ⎜c⋅sin (x)⎟    ⎛ x⎞         x ⎛ x    ⎛ x⎞      ⎛ x⎞⎞ ⎛     2    2⎛ 2
# log(b)⋅log⎜─────────⎟⋅cos⎝b ⎠ - 12⋅a⋅b ⋅⎝b ⋅sin⎝b ⎠ - cos⎝b ⎠⎠⋅⎝2⋅a⋅x ⋅cos ⎝x
#           ⎝    x    ⎠
#
#
#
#
#
#
#                                                            x ⎛           sin(x
#                                        ⎛     2   ⎞   24⋅a⋅b ⋅⎜2⋅cos(x) - ─────
# ⎞      2    ⎛ 2⎞      ⎛ 2⎞⎞    2       ⎜c⋅sin (x)⎟           ⎝             x
# ⎠ + 2⋅x ⋅sin⎝x ⎠ - cos⎝x ⎠⎠⋅log (b)⋅log⎜─────────⎟ + ─────────────────────────
#                                        ⎝    x    ⎠
#
#
#
#
#
#
# )⎞ ⎛     2    2⎛ 2⎞      2    ⎛ 2⎞      ⎛ 2⎞⎞           ⎛ x⎞          ⎛
# ─⎟⋅⎝2⋅a⋅x ⋅cos ⎝x ⎠ + 2⋅x ⋅sin⎝x ⎠ - cos⎝x ⎠⎠⋅log(b)⋅cos⎝b ⎠   16⋅a⋅x⋅⎜2⋅cos(x
#  ⎠                                                                    ⎝
# ──────────────────────────────────────────────────────────── + ───────────────
#                sin(x)
#
#
#
#
#
#
#     sin(x)⎞ ⎛     2  2    3⎛ 2⎞        2    ⎛ 2⎞    ⎛ 2⎞          2⎛ 2⎞      2
# ) - ──────⎟⋅⎝- 2⋅a ⋅x ⋅cos ⎝x ⎠ - 6⋅a⋅x ⋅sin⎝x ⎠⋅cos⎝x ⎠ + 3⋅a⋅cos ⎝x ⎠ + 2⋅x
#       x   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                            sin(x)
#
#                                        ⎛                                    ⎛
#                                        ⎜                                    ⎜
#                                        ⎜    ⎛           sin(x)⎞    2      4⋅⎜s
#                                        ⎜  3⋅⎜2⋅cos(x) - ──────⎟⋅cos (x)     ⎜
#                                        ⎜    ⎝             x   ⎠             ⎝
#     ⎛ 2⎞        ⎛ 2⎞⎞    ⎛ x⎞   16⋅a⋅x⋅⎜- ───────────────────────────── - ────
# ⋅cos⎝x ⎠ + 3⋅sin⎝x ⎠⎠⋅sin⎝b ⎠          ⎜                2
#                                        ⎝             sin (x)
# ───────────────────────────── + ──────────────────────────────────────────────
#
#
#                                         2   ⎞
#   2         2      2⋅sin(x)⋅cos(x)   sin (x)⎟                            3⋅sin
# in (x) - cos (x) + ─────────────── - ───────⎟⋅cos(x)   4⋅sin(x)⋅cos(x) - ─────
#                           x              2  ⎟                                x
#                                         x   ⎠
# ──────────────────────────────────────────────────── + ───────────────────────
#                        2
#                     sin (x)
# ──────────────────────────────────────────────────────────────────────────────
#
#
# 2           2                             2
#  (x)   3⋅cos (x)   6⋅sin(x)⋅cos(x)   3⋅sin (x)
# ──── + ───────── - ─────────────── + ─────────                ⎛           sin(
#            x               2              3                 2⋅⎜2⋅cos(x) - ────
#                           x              x                    ⎝             x
# ────────────────────────────────────────────── - 2⋅cos(x) + ──────────────────
#          sin(x)                                                       x⋅sin(x)
#
# ──────────────────────────────────────────────────────────────────────────────
#                   sin(x)
#
#                ⎛                                         2   ⎞         ⎞
#                ⎜   2         2      2⋅sin(x)⋅cos(x)   sin (x)⎟         ⎟
# x)⎞          2⋅⎜sin (x) - cos (x) + ─────────────── - ───────⎟         ⎟
# ──⎟⋅cos(x)     ⎜                           x              2  ⎟         ⎟
#   ⎠            ⎝                                         x   ⎠   sin(x)⎟    ⎛
# ────────── + ───────────────────────────────────────────────── + ──────⎟⋅sin⎝b
#                                   x⋅sin(x)                         x   ⎟
#                                                                        ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                              ⎛
#                                                              ⎜
#                                                              ⎜  ⎛           si
# x⎞    ⎛ 2⎞                                                   ⎜2⋅⎜2⋅cos(x) - ──
#  ⎠⋅cos⎝x ⎠        ⎛     2    2⎛ 2⎞      2    ⎛ 2⎞      ⎛ 2⎞⎞ ⎜  ⎝
#              12⋅a⋅⎝2⋅a⋅x ⋅cos ⎝x ⎠ + 2⋅x ⋅sin⎝x ⎠ - cos⎝x ⎠⎠⋅⎜────────────────
#                                                              ⎝           sin(x
# ────────── - ─────────────────────────────────────────────────────────────────
#
#
#
#                  ⎛                                         2   ⎞
#                  ⎜   2         2      2⋅sin(x)⋅cos(x)   sin (x)⎟
# n(x)⎞          2⋅⎜sin (x) - cos (x) + ─────────────── - ───────⎟
# ────⎟⋅cos(x)     ⎜                           x              2  ⎟   2⋅cos(x) -
# x   ⎠            ⎝                                         x   ⎠
# ──────────── + ───────────────────────────────────────────────── - ───────────
# )                                    sin(x)                                x
# ──────────────────────────────────────────────────────────────────────────────
#            sin(x)
#
#
#       ⎞
#       ⎟
# sin(x)⎟
# ──────⎟
#   x   ⎟    ⎛ x⎞
# ──────⎟⋅sin⎝b ⎠
#       ⎠               ⎛   3  4    4⎛ 2⎞       2  4    ⎛ 2⎞    2⎛ 2⎞       2  2
# ─────────────── + 4⋅a⋅⎝4⋅a ⋅x ⋅cos ⎝x ⎠ + 24⋅a ⋅x ⋅sin⎝x ⎠⋅cos ⎝x ⎠ - 12⋅a ⋅x
#
#
#
#
#
#
#
#
#
#     3⎛ 2⎞         4    2⎛ 2⎞         4    2⎛ 2⎞         2    ⎛ 2⎞    ⎛ 2⎞
# ⋅cos ⎝x ⎠ + 12⋅a⋅x ⋅sin ⎝x ⎠ - 16⋅a⋅x ⋅cos ⎝x ⎠ - 36⋅a⋅x ⋅sin⎝x ⎠⋅cos⎝x ⎠ + 3⋅
#
#
#
#
#
#
#
#
#                                                           ⎛     2   ⎞
#      2⎛ 2⎞      4    ⎛ 2⎞       2    ⎛ 2⎞        ⎛ 2⎞⎞    ⎜c⋅sin (x)⎟    ⎛ x⎞
# a⋅cos ⎝x ⎠ - 4⋅x ⋅sin⎝x ⎠ + 12⋅x ⋅cos⎝x ⎠ + 3⋅sin⎝x ⎠⎠⋅log⎜─────────⎟⋅sin⎝b ⎠
#                                                           ⎝    x    ⎠
#
#
#                               ⎛                                 ⎛
#                               ⎜                                 ⎜   2
#                               ⎜  ⎛           sin(x)⎞          2⋅⎜sin (x) - cos
#                               ⎜2⋅⎜2⋅cos(x) - ──────⎟⋅cos(x)     ⎜
#      x ⎛ x    ⎛ x⎞      ⎛ x⎞⎞ ⎜  ⎝             x   ⎠            ⎝
#   6⋅b ⋅⎝b ⋅sin⎝b ⎠ - cos⎝b ⎠⎠⋅⎜──────────────────────────── + ────────────────
#                               ⎝           sin(x)
# + ────────────────────────────────────────────────────────────────────────────
#                                                                     sin(x)
#
#
#                             2   ⎞                    ⎞
# 2      2⋅sin(x)⋅cos(x)   sin (x)⎟                    ⎟
#  (x) + ─────────────── - ───────⎟              sin(x)⎟
#               x              2  ⎟   2⋅cos(x) - ──────⎟
#                             x   ⎠                x   ⎟    2         x ⎛
# ───────────────────────────────── - ─────────────────⎟⋅log (b)   4⋅b ⋅⎜2⋅cos(x
#       sin(x)                                x        ⎠                ⎝
# ────────────────────────────────────────────────────────────── - ─────────────
#
#
#
#
#
#
#
#     sin(x)⎞ ⎛ 2⋅x    ⎛ x⎞      x    ⎛ x⎞      ⎛ x⎞⎞    3
# ) - ──────⎟⋅⎝b   ⋅cos⎝b ⎠ + 3⋅b ⋅sin⎝b ⎠ - cos⎝b ⎠⎠⋅log (b)
#       x   ⎠                                                    x ⎛ 3⋅x    ⎛ x⎞
# ─────────────────────────────────────────────────────────── + b ⋅⎝b   ⋅sin⎝b ⎠
#                     sin(x)
#
#                                                                           ⎛
#                                                                           ⎜
#                                                                           ⎜
#                                                                           ⎜  3
#                                                                         x ⎜
#                                                                      8⋅b ⋅⎜- ─
#                                                        ⎛     2   ⎞        ⎜
#       2⋅x    ⎛ x⎞      x    ⎛ x⎞      ⎛ x⎞⎞    4       ⎜c⋅sin (x)⎟        ⎝
#  - 6⋅b   ⋅cos⎝b ⎠ - 7⋅b ⋅sin⎝b ⎠ + cos⎝b ⎠⎠⋅log (b)⋅log⎜─────────⎟ - ─────────
#                                                        ⎝    x    ⎠
#
#                                  ⎛                                         2
#                                  ⎜   2         2      2⋅sin(x)⋅cos(x)   sin (x
#  ⎛           sin(x)⎞    2      4⋅⎜sin (x) - cos (x) + ─────────────── - ──────
# ⋅⎜2⋅cos(x) - ──────⎟⋅cos (x)     ⎜                           x              2
#  ⎝             x   ⎠             ⎝                                         x
# ──────────────────────────── - ───────────────────────────────────────────────
#              2                                            2
#           sin (x)                                      sin (x)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  ⎞                                 2           2                             2
# )⎟                            3⋅sin (x)   3⋅cos (x)   6⋅sin(x)⋅cos(x)   3⋅sin
# ─⎟⋅cos(x)   4⋅sin(x)⋅cos(x) - ───────── + ───────── - ─────────────── + ──────
#  ⎟                                x           x               2              3
#  ⎠                                                           x              x
# ───────── + ──────────────────────────────────────────────────────────────────
#                                             sin(x)
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                       sin(x)
#
#                                                   ⎛
# (x)                                               ⎜   2         2      2⋅sin(x
# ───                ⎛           sin(x)⎞          2⋅⎜sin (x) - cos (x) + ───────
#                  2⋅⎜2⋅cos(x) - ──────⎟⋅cos(x)     ⎜
#                    ⎝             x   ⎠            ⎝
# ─── - 2⋅cos(x) + ──────────────────────────── + ──────────────────────────────
#                            x⋅sin(x)                                  x⋅sin(x)
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#               2   ⎞         ⎞                    ⎛
# )⋅cos(x)   sin (x)⎟         ⎟                    ⎜
# ──────── - ───────⎟         ⎟                    ⎜  ⎛           sin(x)⎞
# x              2  ⎟         ⎟                    ⎜8⋅⎜2⋅cos(x) - ──────⎟⋅cos(x)
#               x   ⎠   sin(x)⎟           ⎛ x⎞     ⎜  ⎝             x   ⎠
# ─────────────────── + ──────⎟⋅log(b)⋅cos⎝b ⎠   2⋅⎜────────────────────────────
#                         x   ⎟                    ⎜           sin(x)
#                             ⎠                    ⎝
# ──────────────────────────────────────────── - ───────────────────────────────
#
#
#                                       ⎛
#                                       ⎜   2         2      2⋅sin(x)⋅cos(x)   s
#       ⎛           sin(x)⎞    3      6⋅⎜sin (x) - cos (x) + ─────────────── - ─
#    12⋅⎜2⋅cos(x) - ──────⎟⋅cos (x)     ⎜                           x
#       ⎝             x   ⎠             ⎝
#  + ────────────────────────────── + ──────────────────────────────────────────
#                  3                                        sin(x)
#               sin (x)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   2   ⎞      ⎛                                         2   ⎞             ⎛
# in (x)⎟      ⎜   2         2      2⋅sin(x)⋅cos(x)   sin (x)⎟    2        ⎜
# ──────⎟   18⋅⎜sin (x) - cos (x) + ─────────────── - ───────⎟⋅cos (x)   6⋅⎜4⋅si
#    2  ⎟      ⎜                           x              2  ⎟             ⎜
#   x   ⎠      ⎝                                         x   ⎠             ⎝
# ─────── + ────────────────────────────────────────────────────────── - ───────
#                                       3
#                                    sin (x)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                    2           2                             2   ⎞
#               3⋅sin (x)   3⋅cos (x)   6⋅sin(x)⋅cos(x)   3⋅sin (x)⎟
# n(x)⋅cos(x) - ───────── + ───────── - ─────────────── + ─────────⎟⋅cos(x)   4⋅
#                   x           x               2              3   ⎟
#                                              x              x    ⎠
# ───────────────────────────────────────────────────────────────────────── - ──
#                                 2
#                              sin (x)
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ⎛                                           2           2
# ⎜   2         2      4⋅sin(x)⋅cos(x)   3⋅sin (x)   3⋅cos (x)   6⋅sin(x)⋅cos(x)
# ⎜sin (x) - cos (x) + ─────────────── - ───────── + ───────── - ───────────────
# ⎜                           x               2           2              3
# ⎝                                          x           x              x
# ──────────────────────────────────────────────────────────────────────────────
#                                           sin(x)
#
# ──────────────────────────────────────────────────────────────────────────────
#            sin(x)
#
#         2   ⎞                                                              ⎛
#    3⋅sin (x)⎟                                                              ⎜
#  + ─────────⎟     ⎛           sin(x)⎞     ⎛           sin(x)⎞    2      12⋅⎜si
#         4   ⎟   3⋅⎜2⋅cos(x) - ──────⎟   9⋅⎜2⋅cos(x) - ──────⎟⋅cos (x)      ⎜
#        x    ⎠     ⎝             x   ⎠     ⎝             x   ⎠              ⎝
# ───────────── - ───────────────────── - ───────────────────────────── - ──────
#                           x                            2
#                                                   x⋅sin (x)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                        2   ⎞            ⎛
#  2         2      2⋅sin(x)⋅cos(x)   sin (x)⎟            ⎜                  3⋅s
# n (x) - cos (x) + ─────────────── - ───────⎟⋅cos(x)   3⋅⎜4⋅sin(x)⋅cos(x) - ───
#                          x              2  ⎟            ⎜
#                                        x   ⎠            ⎝
# ─────────────────────────────────────────────────── + ────────────────────────
#                        2
#                   x⋅sin (x)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   2           2                             2   ⎞⎞        ⎞
# in (x)   3⋅cos (x)   6⋅sin(x)⋅cos(x)   3⋅sin (x)⎟⎟        ⎟
# ────── + ───────── - ─────────────── + ─────────⎟⎟        ⎟
#  x           x               2              3   ⎟⎟        ⎟
#                             x              x    ⎠⎟    ⎛ x⎞⎟
# ─────────────────────────────────────────────────⎟⋅sin⎝b ⎠⎟
#          x⋅sin(x)                                ⎟        ⎟        ⎛ 2⎞
#                                                  ⎠        ⎟  -a⋅sin⎝x ⎠
# ──────────────────────────────────────────────────────────⎟⋅ℯ
#                                                           ⎠

# %% [markdown]
# Numerical case

# %%
k = pd.read_csv('test.csv')

# %%
k.columns
# Out:
# Index(['d', 't'], dtype='object')

# %%
plt.plot(k['t'])

plt.show()

# %%
g = np.array([3, 5, 6,7])

plt.plot(g)
plt.show()
