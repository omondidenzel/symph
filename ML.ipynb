# %% [markdown]
# # Linear regression

# %%
#!pip install pandas 
#!pip install numpy
#!pip install seaborn

# %%
# Modules
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
plt.plot(np.array([3, 5, 6,7]))

plt.show()

# %%
df =pd.read_csv("test.csv")
df.head()
# Out:
#           d         t
# 0  0.191599  0.683453
# 1  0.010298  0.029440
# 2  0.220186  0.329827
# 3  0.537428  0.570302
# 4  0.476384  0.321271

# %%
plt.plot(df.d, df.t)
